# %%
# Run `jupyter notebook` in the braidpool/tests directory, or add the path to the tests/ directory here
#sys.path.append('../braidpool/tests/') 
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
plt.rcParams['figure.figsize'] = [12,4]
from joblib import Parallel, delayed, cpu_count
from functools import reduce
import numpy as np
import scipy
from scipy.special import lambertw as W
import time
import braid
from simulator import *

# %%
# Generate a random braid to demonstrate the code. Re-run this block to generate a different braid.
# The target and hashrate parameters are measured on my CPU (Intel 3.3 GHz) Run `simulator.py --mine` to benchmark your CPU
n = Network(nnodes=25, target=2**240-1, hashrate=800000)
# Use `mine=False` to use the geometric distribution to simulate mining. Use `mine=True` to actually compute sha256d hashes (slower)
n.simulate(nbeads=30, mine=False) 

# Each node has its own braid, look at node 0's braid here.
b = n.nodes[0].braid
# Extract the `parents` dict as integers (hashes) instead of instances of the <Bead> object
hashed_parents = {int(k): set(map(int, v)) for k,v in dict(b).items()}
# Remap integers (hashes) in the parents array to sequential integers for display purposes
parents  = braid.number_beads(hashed_parents)
children = braid.reverse(parents)
work     = braid.descendant_work(parents)
hwpath   = braid.highest_work_path(parents, children)
cohorts  = list(braid.cohorts(parents))
print(f"Generated braid: {len(b.beads)} beads with {len(cohorts)} cohorts, {len(b.tips)} tips, "
      f"and {len(hwpath)} beads in the highest work path.")
fig = b.plot()
# Out:
# Generated braid: 31 beads with 20 cohorts, 1 tips, and 23 beads in the highest work path.

# %%
# Generate a random "thin braid".
n = Network(nnodes=50, target=2**238-1) # difficulty 2**238-1 is "high" for a global network with CPU mining
n.simulate(nbeads=10, mine=False)
fig = n.nodes[0].braid.plot()
# Create a sequentially-numbered parents dict which is nice for display instead of hashes from the simulator
hashed_parents = {int(k): set(map(int, v)) for k,v in dict(n.nodes[0].braid).items()}
parents = braid.number_beads(hashed_parents)
print("parents = ", parents)
# Out:
# parents =  {0: set(), 1: {0}, 2: {1}, 3: {2}, 4: {2}, 5: {2}, 6: {3, 4, 5}, 7: {6}, 8: {7}, 9: {8}, 10: {8}}

# %%
# Generate Fig 1 for braid_consensus.md. Your braid above is random and won't be the same.
parents = {0: set(), 1: {0}, 2: {1}, 3: {2}, 4: {3}, 5: {4}, 6: {5}, 7: {6}, 8: {7}, 9: {7}, 10: {9,8}}
b = Braid(parents=parents)
b.plot("/tmp/thin_braid.png")

# %%
# Generate the "thick braid" graph.
n = Network(nnodes=50, target=2**241-1) # difficulty 2**238-1 is "high" for a global network with CPU mining
n.simulate(nbeads=40, mine=False)
fig = n.nodes[0].braid.plot()
# Create a sequentially-numbered parents dict which is nice for display instead of hashes from the simulator
hashed_parents = {int(k): set(map(int, v)) for k,v in dict(n.nodes[0].braid).items()}
parents = braid.number_beads(hashed_parents)
print("parents = ", parents)
# Out:
# parents =  {0: set(), 1: {0}, 2: {0}, 3: {0}, 4: {0}, 5: {8, 1, 4, 7}, 6: {1, 4, 7}, 7: {2, 3}, 8: {2, 3}, 9: {17, 18, 19, 5}, 10: {12, 5}, 11: {17, 18, 19, 5}, 12: {8, 6}, 13: {16, 9, 15}, 14: {16, 9, 15}, 15: {10, 11}, 16: {19, 17, 10, 18}, 17: {12}, 18: {12}, 19: {12}, 20: {13}, 21: {20, 14}, 22: {20, 14}, 23: {20, 14}, 24: {21, 22, 23}, 25: {27, 21}, 26: {22, 23}, 27: {22, 23}, 28: {24, 26, 27}, 29: {25, 28}, 30: {25, 28}, 31: {25, 28}, 32: {25, 28}, 33: {25, 28}, 34: {32, 33, 29, 30, 31}, 35: {32, 29, 30, 31}, 36: {32, 33, 37, 29, 30}, 37: {31}, 38: {34, 35, 37}, 39: {36, 38}, 40: {39}}

# %%
# Generate Fig.2 for braid_consensus.md. Your braid above is random and won't be the same.
parents = {0: set(), 1: {0}, 2: {0}, 3: {1, 2}, 4: {1, 2}, 5: {1, 2}, 6: {2}, 7: {9, 3, 5}, 8: {9, 10, 3, 5}, 9: {4, 6}, 10: {4, 6}, 11: {4, 5, 6}, 12: {10, 5}, 13: {10, 5}, 14: {7, 8, 11, 12, 13}, 15: {7, 8, 11, 12, 13}, 16: {14, 15}, 17: {16}, 18: {16}, 19: {16}, 20: {16}, 21: {16}, 22: {17, 18, 19, 20, 21}, 23: {17, 18, 19, 20, 21}, 24: {22, 23}, 25: {23}, 26: {24, 25}, 27: {24, 25}, 28: {24, 25}, 29: {32, 26, 28}, 30: {32, 26, 28}, 31: {32, 26, 28}, 32: {27}, 33: {29, 30, 31}, 34: {29, 30, 31}, 35: {33, 34}, 36: {35}, 37: {35}, 38: {36, 37}, 39: {36, 37}}
b = Braid(parents=parents)
b.plot("/tmp/thick_braid.png")

# %%
# This takes a few minutes to run, where the points on the right edge take the most time because N_B/N_C is large
# Change N_COHORTS to increase the accuracy of the simulation
N_COHORTS = 50
# x = MAX_HASH*exp(MIN_LOG_X) is the minimum difficulty we will consder (lower this at your peril--takes exponentially slower)
# -9.5  8.39s  on 20 cores
# -9.25 17.5s  on 20 cores
# -9.0  47.43s on 20 cores
# -8.75 crashes OOM
MIN_LOG_X = -9.25

start = time.time()
# Define a function which collects times and beads as a function of target difficulty
dctimes = []
def gettimes(target, ncohorts=N_COHORTS):
    # re-use the same network so we don't generate differences due to different network topology, and disable difficulty adjustment
    random.seed(1) # Make sure they use the same seed so they all generate the same network
    net = Network(nnodes=25, target=target, hashrate=800000, target_algo="fixed")
    b = net.nodes[0].braid
    # Try to get roughly the same number of cohorts for each simulation point in <target>
    cache = {} # Use an ancestor cache because this loop recalculates cohorts a lot and it's slow for large cohorts

    # This is a bit of a cheat. We could run in a loop until we have enough cohorts, but because after each iteration we have to
    # recompute cohorts, this gets expensive when cohorts are large. So we calculate how many beads we need for N_COHORTS cohorts
    x = target/MAX_HASH
    alambda = net.hashrate/net.nnodes # FIXME times a?
    nbeads = (1 + alambda*x*exp(alambda*x))*ncohorts
    
    #nbeads = ncohorts/5 if target/MAX_HASH < 3e-5 else 500 # Do longer runs at low difficulty (N_B/N_C >~ 100)
    #while len(b.cohorts) < ncohorts:
    net.simulate(nbeads=nbeads, mine=False)
    parents = {b.beads[bead_hash]: b.beads[bead_hash].parents for bead_hash in b.beads}
    b.cohorts = list(braid.cohorts(b.parents(), ancestor_cache=cache))

    dt = np.diff([np.mean([b.t for b in c]) for c in b.cohorts])
    msg = f"At x= {target/float(MAX_HASH)} we generated {len(b.beads)} beads and {len(b.cohorts)} cohorts"
    return((float(target)/float(MAX_HASH), np.mean(dt), np.std(dt), len(b.beads), len(b.cohorts), msg))
    
# Run this function in parallel for the number of cores on your machine.
dctimes = Parallel(n_jobs=cpu_count(), backend="threading")(delayed(gettimes)(d) 
                                                            for d in map(int, MAX_HASH*np.exp(np.arange(MIN_LOG_X, -20, -0.25))))
end = time.time()
#for data in dctimes: print(data[-1])
print(f"Run time: {end-start:6.2f}s")
# Out:
# Run time:  16.88s

# %%
# Generate Figure 3 for braid_consensus.md
plt.rcParams['figure.figsize'] = [12,8]
x      = np.array([p[0] for p in dctimes])
Tcs    = np.array([p[1] for p in dctimes])
Tcserr = np.array([p[2] for p in dctimes])
Nb_Nc  = np.array([p[3]/p[4] for p in dctimes])

# Perform the curve fit for T_C in log coordinates
def f(x,lam,a): return 1/lam/x+a*np.exp(lam*a*x)
def logf(logx, lam, a): return np.log(f(np.exp(logx), lam, a))
((lam,a),dummy) = scipy.optimize.curve_fit(logf, np.log(x), np.log(Tcs), [1e7, 1e-3], bounds=([0, 0],[np.inf, np.inf]))
x0 = 2/lam/a*scipy.special.lambertw(1/2).real

# Perform the curve fit for $N_B/N_C$ where b = a*lambda
def nbnc(x, b): return 1.0+b*x*np.exp(b*x)
((b,), dummy) = scipy.optimize.curve_fit(nbnc, x, Nb_Nc)
print(f"lambda = {lam}, a={a}, x0={x0}, b= {b} = {a*lam}")

# Plot it
fig, (ax1, ax2) = plt.subplots(2,1,sharex=True, height_ratios=[1.5,1])
data1 = ax1.scatter(x, Tcs/a, label="Simulated cohort time $T_C/a$")
data2 = ax2.scatter(x, Nb_Nc, label="Simulated $N_B/N_C$", color='green')
ax2.set_ylabel("Beads per cohort $N_B/N_C$")
ax2.set_yscale('log')
x_analytic = np.logspace(log(min(x)), log(max(x)), 100, base=np.e)
data3, = ax1.loglog(x_analytic, f(x_analytic, lam, a)/a, label="Best fit $\\frac{T_C}{a} = \\frac{1}{a\lambda x} + e^{a \lambda x}$", color='orange');
data4 = ax1.axvline(np.real(x0), color='red', label=f"Best fit $x_0$")
ax2.set_xlabel('target difficulty in units of MAX_HASH')
ax2.axvline(np.real(x0), color='red', label=f"Best fit $x_0$")
data5, = ax2.plot(x_analytic, nbnc(x_analytic, a*lam), label="Best fit $\\frac{N_B}{N_C} = 1+a\lambda x e^{a\lambda x}$")
data6 = ax2.axhline(2.42, color='purple', label="Target $\\frac{N_B}{N_C} = 2.42$ @ $x_0$")
ax1.set_ylabel('Cohort time in units of latency $T_C/a$')

fig.subplots_adjust(hspace=0)
fig.legend(#loc="upper center", 
           bbox_to_anchor=(0.38,0.685), 
           handles=[data1, data2, data3, data4, data5, data6,
                    #Patch(color='white', label=f"Best fit $a$  = {a*1000:3.3} ms"),
                    Patch(color='white', label="Minimum cohort time $T_{C,min} = " + f"{1.0/a/lam/x0 + np.exp(a*lam*x0):1.3} a$")]);
                    #Patch(color='white', label=f"Best fit $\lambda$  = {lam/1_000_000:3.3} MH/s")]);
ax1.set_title(f"Network simulation with {len(n.nodes)} nodes");
fig.savefig("/tmp/T_C_x.png")
# Out:
# lambda = 12256976.581789454, a=0.0029822135124563057, x0=1.9245176574421344e-05, b= 36976.248178233065 = 36552.92118407301

# %%
NBEADS = 1000000 # Increase to make the graphs smoother

n.reset(target=int(Fraction(x0)*MAX_HASH))
n.simulate(nbeads=NBEADS)
cohorts_x0 =  list(braid.cohorts(braid.number_beads({int(k): set(map(int, v)) for k,v in dict(n.nodes[0].braid).items()})))

chunked_cohorts_1_x0 = [sum(len(c) for c in cohorts_x0[i:i+1]) for i in range(0, len(cohorts_x0) - (len(cohorts_x0)%1), 1)]
chunked_cohorts_3_x0 = [sum(len(c) for c in cohorts_x0[i:i+3]) for i in range(0, len(cohorts_x0) - (len(cohorts_x0)%3), 3)]
chunked_cohorts_7_x0 = [sum(len(c) for c in cohorts_x0[i:i+7]) for i in range(0, len(cohorts_x0) - (len(cohorts_x0)%7), 7)]
bins = np.arange(0.5, 100.5, 1)
width = np.diff(bins)
centers = (bins[:-1] + bins[1:]) / 2
counts1_x0, _ = np.histogram(chunked_cohorts_1_x0, bins=bins)
counts3_x0, _ = np.histogram(chunked_cohorts_3_x0, bins=bins)
counts7_x0, _ = np.histogram(chunked_cohorts_7_x0, bins=bins)

# Plot with error bars
#plt.bar(centers, counts1, yerr=np.sqrt(counts1), width=width, alpha=0.5, label='$N_C=1$ Cohort', edgecolor='blue', capsize=5)
#plt.bar(centers, counts3, yerr=np.sqrt(counts3), width=width, alpha=0.5, label='$N_C=3$ Cohorts', edgecolor='orange', capsize=5)
#plt.bar(centers, counts7, yerr=np.sqrt(counts7), width=width, alpha=0.5, label='$N_C=7$ Cohorts', edgecolor='green', capsize=5)
plt.bar(centers, counts1_x0, width=width, alpha=0.5, label='$N_C=1$ Cohort',  edgecolor='blue', capsize=5)
plt.bar(centers, counts3_x0, width=width, alpha=0.5, label='$N_C=3$ Cohorts', edgecolor='orange', capsize=5)
plt.bar(centers, counts7_x0, width=width, alpha=0.5, label='$N_C=7$ Cohorts', edgecolor='green', capsize=5)

plt.xlim(0.5, max(bins))
plt.title(f"Histogram of $\sum N_B$ within $N_C$ cohorts ({len(n.nodes[0].braid.beads)} beads, {len(cohorts)} cohorts, "
          f"$N_B/N_C={len(n.nodes[0].braid.beads)/len(cohorts):0.2f}$) @ $x=x_0$")
plt.xlabel("$N_B$ within $N_C$ cohorts")
plt.ylabel('Count')
plt.yscale('log')
plt.legend()
plt.show()

# %%
# Double the target (increase N_B/N_C)
n.reset(target=int(Fraction(2*x0)*MAX_HASH))
n.simulate(nbeads=NBEADS)
cohorts_2x0 =  list(braid.cohorts(braid.number_beads({int(k): set(map(int, v)) for k,v in dict(n.nodes[0].braid).items()})))

chunked_cohorts_1_2x0 = [sum(len(c) for c in cohorts_2x0[i:i+1]) for i in range(0, len(cohorts_2x0) - (len(cohorts_2x0)%1), 1)]
chunked_cohorts_3_2x0 = [sum(len(c) for c in cohorts_2x0[i:i+3]) for i in range(0, len(cohorts_2x0) - (len(cohorts_2x0)%3), 3)]
chunked_cohorts_7_2x0 = [sum(len(c) for c in cohorts_2x0[i:i+7]) for i in range(0, len(cohorts_2x0) - (len(cohorts_2x0)%7), 7)]
counts1_2x0, _ = np.histogram(chunked_cohorts_1_2x0, bins=bins)
counts3_2x0, _ = np.histogram(chunked_cohorts_3_2x0, bins=bins)
counts7_2x0, _ = np.histogram(chunked_cohorts_7_2x0, bins=bins)

plt.bar(centers, counts1_2x0, width=width, alpha=0.5, label='$N_C=1$ Cohort', edgecolor='blue', capsize=5)
plt.bar(centers, counts3_2x0, width=width, alpha=0.5, label='$N_C=3$ Cohorts', edgecolor='orange', capsize=5)
plt.bar(centers, counts7_2x0, width=width, alpha=0.5, label='$N_C=7$ Cohorts', edgecolor='green', capsize=5)

plt.xlim(0.5, max(bins))
plt.title(f"Histogram of $\sum N_B$ within $N_C$ cohorts ({len(n.nodes[0].braid.beads)} beads, {len(cohorts)} cohorts, "
          f"$N_B/N_C={len(n.nodes[0].braid.beads)/len(cohorts):0.2f}$) @ $x=2 x_0$")
plt.xlabel("$N_B$ within $N_C$ cohorts")
plt.ylabel('Count')
plt.yscale('log')
plt.legend()
plt.show()

# %%
# Halve the target (decrease N_B/N_C)
n.reset(target=int(Fraction(x0/2)*MAX_HASH))
n.simulate(nbeads=NBEADS)
cohorts_x0_2 =  list(braid.cohorts(braid.number_beads({int(k): set(map(int, v)) for k,v in dict(n.nodes[0].braid).items()})))

chunked_cohorts_1_x0_2 = [sum(len(c) for c in cohorts_x0_2[i:i+1]) for i in range(0, len(cohorts_x0_2) - (len(cohorts_x0_2)%1), 1)]
chunked_cohorts_3_x0_2 = [sum(len(c) for c in cohorts_x0_2[i:i+3]) for i in range(0, len(cohorts_x0_2) - (len(cohorts_x0_2)%3), 3)]
chunked_cohorts_7_x0_2 = [sum(len(c) for c in cohorts_x0_2[i:i+7]) for i in range(0, len(cohorts_x0_2) - (len(cohorts_x0_2)%7), 7)]
counts1_x0_2, _ = np.histogram(chunked_cohorts_1_x0_2, bins=bins)
counts3_x0_2, _ = np.histogram(chunked_cohorts_3_x0_2, bins=bins)
counts7_x0_2, _ = np.histogram(chunked_cohorts_7_x0_2, bins=bins)

plt.bar(centers, counts1_x0_2, width=width, alpha=0.5, label='$N_C=1$ Cohort', edgecolor='blue', capsize=5)
plt.bar(centers, counts3_x0_2, width=width, alpha=0.5, label='$N_C=3$ Cohorts', edgecolor='orange', capsize=5)
plt.bar(centers, counts7_x0_2, width=width, alpha=0.5, label='$N_C=7$ Cohorts', edgecolor='green', capsize=5)

plt.xlim(0.5, max(bins))
plt.title(f"Histogram of $\\sum N_B$ within $N_C$ cohorts ({len(n.nodes[0].braid.beads)} beads, {len(cohorts)} cohorts, "
          f"$N_B/N_C={len(n.nodes[0].braid.beads)/len(cohorts):0.2f}$) @ $x=" + "\\frac{x_0}{2}$")
plt.yscale('log')
plt.xlabel("$N_B$ within $N_C$ cohorts")
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
counts1_x0_2, _ = np.histogram(chunked_cohorts_1_x0_2, bins=bins)
counts1_x0, _   = np.histogram(chunked_cohorts_1_x0, bins=bins)
counts1_2x0, _  = np.histogram(chunked_cohorts_1_2x0, bins=bins)

plt.bar(centers, counts1_x0_2, width=width, alpha=0.5, edgecolor='blue',   label='$x=\\frac{x_0}{2}$')
plt.bar(centers, counts1_x0,   width=width, alpha=0.5, edgecolor='orange', label='$x=x_0$')
plt.bar(centers, counts1_2x0,  width=width, alpha=0.5, edgecolor='green',  label='$x=2x_0$')
plt.yscale('log')
plt.title("Histogram of $\sum N_B$ within 1 cohort for different targets $x$")
plt.xlabel("$N_B$ within 1 cohort")
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
counts3_x0_2, _ = np.histogram(chunked_cohorts_3_x0_2, bins=bins)
counts3_x0, _   = np.histogram(chunked_cohorts_3_x0, bins=bins)
counts3_2x0, _  = np.histogram(chunked_cohorts_3_2x0, bins=bins)

plt.bar(centers, counts3_x0_2, width=width, alpha=0.5, edgecolor='blue',   label='$x=\\frac{x_0}{2}$')
plt.bar(centers, counts3_x0,   width=width, alpha=0.5, edgecolor='orange', label='$x=x_0$')
plt.bar(centers, counts3_2x0,  width=width, alpha=0.5, edgecolor='green',  label='$x=2x_0$')
plt.title("Histogram of $\sum N_B$ within 3 cohorts for different targets $x$")
plt.xlabel("$N_B$ within $N_C=3$ cohorts")
plt.ylabel('Count')
plt.legend()
plt.yscale('log')
plt.show()

# %%
counts7_x0_2, _ = np.histogram(chunked_cohorts_7_x0_2, bins=bins)
counts7_x0, _   = np.histogram(chunked_cohorts_7_x0, bins=bins)
counts7_2x0, _  = np.histogram(chunked_cohorts_7_2x0, bins=bins)

plt.bar(centers, counts7_x0_2, width=width, alpha=0.5, edgecolor='blue',   label='$x=\\frac{x_0}{2}$')
plt.bar(centers, counts7_x0,   width=width, alpha=0.5, edgecolor='orange', label='$x=x_0$')
plt.bar(centers, counts7_2x0,  width=width, alpha=0.5, edgecolor='green',  label='$x=2x_0$')
plt.title("Histogram of $\sum N_B$ within 7 cohorts for different targets $x$")
plt.xlabel("$N_B$ within $N_C=7$ cohorts")
plt.ylabel('Count')
plt.legend()
plt.yscale('log')
plt.show()

# %%
N = 7

n.reset(target=int(Fraction(x0)*MAX_HASH), target_algo='exp')
n.simulate(nbeads=NBEADS)
cohorts_exp =  list(braid.cohorts(braid.number_beads({int(k): set(map(int, v)) for k,v in dict(n.nodes[0].braid).items()})))
chunked_cohorts_7_exp = [sum(len(c) for c in cohorts_exp[i:i+N]) for i in range(0, len(cohorts_exp) - (len(cohorts_exp)%N), N)]
counts7_exp, _ = np.histogram(chunked_cohorts_7_exp, bins=bins)

#n.reset(target=int(Fraction(x0)*MAX_HASH), target_algo='simple')
#n.simulate(nbeads=NBEADS)
#cohorts_simple =  list(braid.cohorts(braid.number_beads({int(k): set(map(int, v)) for k,v in dict(n.nodes[0].braid).items()})))
#chunked_cohorts_7_simple = [sum(len(c) for c in cohorts_simple[i:i+N]) for i in range(0, len(cohorts_simple) - (len(cohorts_simple)%N), N)]
#counts7_simple, _ = np.histogram(chunked_cohorts_7_simple, bins=bins)

n.reset(target=int(Fraction(x0)*MAX_HASH), target_algo='zeno')
n.simulate(nbeads=NBEADS)
cohorts_zeno =  list(braid.cohorts(braid.number_beads({int(k): set(map(int, v)) for k,v in dict(n.nodes[0].braid).items()})))
chunked_cohorts_7_zeno = [sum(len(c) for c in cohorts_zeno[i:i+N]) for i in range(0, len(cohorts_zeno) - (len(cohorts_zeno)%N), N)]
counts7_zeno, _ = np.histogram(chunked_cohorts_7_zeno, bins=bins)

# %%
plt.bar(centers, counts7_x0,     width=width, alpha=0.5, label='No DAA', edgecolor='blue')
#plt.bar(centers, counts7_exp,    width=width, alpha=0.5, label='EMA DAA', edgecolor='orange')
#plt.bar(centers, counts7_simple, width=width, alpha=0.5, label='Simple DAA', edgecolor='green')
plt.bar(centers, counts7_zeno, width=width, alpha=0.5, label='Zeno DAA', edgecolor='yellow')
#plt.bar(centers, counts7, width=width, alpha=0.5, label='$N_C=7$ Cohorts', edgecolor='green', capsize=5)

plt.xlim(0.5, max(bins))
plt.title(f"Histogram of $\sum N_B$ within $N_C$ cohorts ({len(n.nodes[0].braid.beads)} beads, {len(cohorts)} cohorts, "
          f"$N_B/N_C={len(n.nodes[0].braid.beads)/len(cohorts):0.2f}$) with different DAAs")
plt.xlabel("$N_B$ within $N_C=7$ cohorts")
plt.ylabel('Count')
plt.yscale('log')
plt.legend()
plt.show()

# %%
print(sum(counts7_x0), sum(counts7_zeno))

# %%
NBEADS = 100 # Increase to make the graphs smoother

n.reset(target=int(Fraction(x0)*MAX_HASH))
n.simulate(nbeads=NBEADS)
n.nodes[0].braid.cohorts = list(braid.cohorts(dict(n.nodes[0].braid)))

# %%
n.nodes[0].braid.alambda(7)
# Out:
# np.float64(21873.04192595673)

# %%
sum(len(c) for c in n.nodes[0].braid.cohorts[-7:])
# Out:
# 21

# %%
n.nodes[0].calc_target_harmonic([b for c in n.nodes[0].braid.cohorts[:-7] for b in c])
# Out:
# 1968422999097594814152721046373092774701656183542325074449170826044680638

# %%
# Cohorts algorithm time complexity

# %%
# Since the difficulty is changing with every bead, it's not really possible to measure b = \sqrt{2} a \lambda
# while in operation, unfortunately.
print(f"b                 = {b}")
print(f"sqrt(2)*a*lambda  = {sqrt(2)*a*lam}")
print(f"a*lambda/W(1/2)/2 = {a*lam/W(1/2).real/2}")
# Out:
# b                 = 60380.826943268614
# sqrt(2)*a*lambda  = 64493.96759729125
# a*lambda/W(1/2)/2 = 64827.6243862229
# At x= 1.300729765406762e-05 we generated 151 beads and 68 cohorts
# At x= 2.7536449349747158e-05 we generated 251 beads and 54 cohorts
# At x= 1.670170079024566e-05 we generated 151 beads and 67 cohorts
# At x= 5.602796437537268e-09 we generated 51 beads and 51 cohorts
# At x= 6.475952175842209e-07 we generated 101 beads and 98 cohorts
# At x= 7.485182988770058e-05 we generated 4501 beads and 50 cohorts
# At x= 4.5399929762484854e-05 we generated 1001 beads and 74 cohorts
# At x= 2.1445408316589164e-05 we generated 201 beads and 55 cohorts
# At x= 1.0677040100347827e-06 we generated 101 beads and 96 cohorts
# At x= 6.82560337633487e-08 we generated 51 beads and 51 cohorts
# At x= 9.237449661970594e-09 we generated 51 beads and 51 cohorts
# At x= 7.889324827200223e-06 we generated 101 beads and 74 cohorts
# ...

# %%
len(n.nodes[0].braid.beads)
# Out:
# 41

# %%
# Difficulty adjustment tests
n.reset(target_algo="simple")
n.simulate(1000)

# %%
TARGET_NB = 247
TARGET_NC = 102
N_BEADS   = 5000 # Number of beads per run
N_RUNS    = 5    # Number of runs to average
# Get cohort times for one run (we will do this in parallel for speed)
def get_cohort_times(n):
    # Generator for a moving average
    def ma_iterate(L, chunk_size=TARGET_NC):
        for i in range(0, len(L), chunk_size):
            yield L[i:i+chunk_size]

    n.reset(target_algo="simple")
    n.simulate(N_BEADS)
    for cohorts in ma_iterate(n.nodes[0].braid.cohorts):
        beads = set.union(*cohorts)
        ma_nbnc_times[np.median([b.t for b in beads])] = len(beads)/TARGET_NC
    return ma_nbnc_times
ma_nbnc_times = reduce(lambda x,y: {**x, **y}, Parallel(n_jobs=cpu_count())(delayed(get_cohort_times)(n) for _ in range(N_RUNS)))

# %%
x2 = np.convolve(x, np.ones(N_RUNS)/N_RUNS, mode='valid')
y2 = np.convolve(y, np.ones(N_RUNS)/N_RUNS, mode='valid')
fig,ax = plt.subplots()
ax.scatter(x2, y2)
ax.axhline(2.42, color='purple')

# %%
#mactimes = np.convolve(nb_nc, np.ones(7)/7, mode='valid')
#plt.scatter(ctimes, nb_nc)
fix,ax = plt.subplots()
x = np.array(list(sorted(ma_nbnc_times.keys())))
y = np.array(list(ma_nbnc_times[xi] for xi in x))
ax.scatter(x, y)
ax.axhline(2.42, color='purple')
